# %%
from pyspark.sql import SparkSession


app = SparkSession.builder.appName("Spark SQL Example").getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/06/06 14:23:43 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
from pyspark.pandas import read_excel

df = read_excel("./data/Datos mismo archivo.xlsx", sheet_name=0, na_values=["NA", "NaN", "", "na", "N/A", "en estudio"])
# Out:
# /usr/local/lib/python3.14/site-packages/pyspark/pandas/__init__.py:43: UserWarning: 'PYARROW_IGNORE_TIMEZONE' environment variable was not set. It is required to set this environment variable to '1' in both driver and executor sides if you use pyarrow>=2.0.0. pandas-on-Spark will set it for you but it does not work if there is a Spark context already launched.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from pyspark.pandas import read_excel
#       2
#       3 df = read_excel("./data/Datos mismo archivo.xlsx", sheet_name=0, na_values=["NA", "NaN", "", "na", "N/A", "en estudio"])
#
# File /usr/local/lib/python3.14/site-packages/pyspark/pandas/__init__.py:59
#      57 from pyspark.pandas.indexes.timedelta import TimedeltaIndex
#      58 from pyspark.pandas.series import Series
# ...
