# %%
from pyspark.sql import SparkSession


app = SparkSession.builder.appName("Spark SQL Example").getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/06/06 15:40:38 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
from etl.load import load_to_db
from etl.extract import extract_sql, extract_excel
from constants import NUMS, BOOLEANS

COLS = NUMS + BOOLEANS + ["Edad", "Género", "Otra Enfermedad", "Fiebre", "TEP"]

df = extract_excel(app, "./data/Datos mismo archivo.xlsx", "Total", COLS)
# Out:
# ---------------------------------------------------------------------------
# PySparkTypeError                          Traceback (most recent call last)
# Cell In[2], line 7
#       3 from constants import NUMS, BOOLEANS
#       4
#       5 COLS = NUMS + BOOLEANS + ["Edad", "Género", "Otra Enfermedad", "Fiebre", "TEP"]
#       6
# ----> 7 df = extract_excel(app, "./data/Datos mismo archivo.xlsx", "Total", COLS)
#
# File /app/etl/extract.py:21, in extract_excel(spark_session, path, sheet_name, columns)
#      19 NA = ["NA", "NaN", "", "na", "N/A", "en estudio"]
#      20 DF = read_excel(path, sheet_name=sheet_name, na_values=NA, usecols=columns)
# ---> 21 return spark_session.createDataFrame(DF)
#
# File /usr/local/lib/python3.14/site-packages/pyspark/sql/session.py:1597, in SparkSession.createDataFrame(self, data, schema, samplingRatio, verifySchema)
#    1593     data = pd.DataFrame(data, columns=column_names)
#    1595 if has_pandas and isinstance(data, pd.DataFrame):
# ...
